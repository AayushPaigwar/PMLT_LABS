# %% [markdown]
# <a href="https://colab.research.google.com/github/AayushPaigwar/PMLT_LABS/blob/master/%5BMLT%5DPract_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
import tensorflow as tf

# %%
m1 = tf.constant(3)
m2 = tf.constant(4)

# %%
m1,m2
# Out:
# (<tf.Tensor: shape=(), dtype=int32, numpy=3>,
#  <tf.Tensor: shape=(), dtype=int32, numpy=4>)

# %%
m3 = tf.multiply(m1,m2)
m3
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=12>

# %%
m4 = tf.add(m1,m2)
m4
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=7>

# %%
m5 = tf.subtract(m1,m2)
m5
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=-1>

# %%
m6 = tf.divide(m1,m2)
m6
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.75>

# %%
m7 = tf.pow(m1,m2)
m7
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=81>

# %%
m8 = tf.square(m1)
m8
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=9>

# %%
m9= tf.constant ([1,2,3,4,5])
m9
# Out:
# <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 2, 3, 4, 5], dtype=int32)>

# %%
m9
# Out:
# <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 2, 3, 4, 5], dtype=int32)>
